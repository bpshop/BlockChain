# %% [markdown]
# # Beispiel zur Hash Funktion
#
# ## Import von Libraries

# %%
import datetime

# %% [markdown]
# ## Referenz-Hash
#
# ![image.png](attachment:image.png)

# %%
reference_hash = 5488078448750364451

year = 1955
month = 4
day = 11

my_date = '{:04d}-{:02d}-{:02d}'.format(year, month, day)
print('Datum: ' + my_date)

my_hash = hash(my_date)
print('Hash-Wert des neuen Datums: ' + str(my_hash))

print('Referenz-Hash:              ' + str(reference_hash))

if reference_hash == my_hash:
    print('Ergebnis: Richtig geraten')
else:
    print('Ergebnis: Falsch geraten')
# Out:
# Datum: 1955-04-11
# Hash-Wert des neuen Datums: 3233294846897348100
# Referenz-Hash:              5488078448750364451
# Ergebnis: Falsch geraten
